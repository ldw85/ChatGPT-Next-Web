# %% [markdown]
# <a href="https://colab.research.google.com/github/ldw85/ChatGPT-Next-Web/blob/main/Embedchain_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Embedchain
#
# Embedchain is a framework to easily create LLM powered bots over any dataset.
#
# Here is a very simple demo about how it work!

# %% [markdown]
# First of all we install the dependencies:

# %%
# !pip install --upgrade embedchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.0/399.0 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 24.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 34.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 5.8 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %% [markdown]
# Now we import the dependencies:

# %%
import os

from embedchain import App

# %% [markdown]
# We instanciate the embechain bot. Remember to change the API key with you OpenAI api key.

# %%
os.environ["OPENAI_API_KEY"] = "YOUR API KEY"

elon_bot = App()

# %% [markdown]
# Now, add different data sources using embedchain's `.add()` method:

# %%
elon_bot.add("web_page", "https://en.wikipedia.org/wiki/Elon_Musk")
elon_bot.add("web_page", "https://tesla.com/elon-musk")
elon_bot.add("youtube_video", "https://www.youtube.com/watch?v=MxZpaJK74Y4")
# Out:
# Successfully saved https://en.wikipedia.org/wiki/Elon_Musk. New chunks count: 359
# All data from https://tesla.com/elon-musk already exists in the database.
# Successfully saved https://www.youtube.com/watch?v=MxZpaJK74Y4. New chunks count: 9

# %% [markdown]
# Your bot is ready now. Ask your bot any questions using `.query()` method:

# %%
elon_bot.query("How many companies does Elon Musk run?")
# Out:
# 'Elon Musk runs multiple companies. Some of the notable ones include SpaceX, Tesla, Neuralink, and The Boring Company. However, the exact number of companies he currently runs may vary as he is involved in various ventures and investments.'

# %%
import os
from embedchain import CustomApp
from embedchain.config import CustomAppConfig
from embedchain.models import Providers, EmbeddingFunctions
from chromadb.utils import embedding_functions
os.environ["OPENAI_API_KEY"] = "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"
config = CustomAppConfig(log_level="DEBUG",embedding_fn=EmbeddingFunctions.HUGGING_FACE,
    embedding_fn_model='intfloat/e5-base-v2',provider=Providers.OPENAI)
naval_chat_bot = CustomApp(config)
# Embed online resources
naval_chat_bot.add("web_page", "https://en.wikipedia.org/wiki/Elon_Musk")
naval_chat_bot.query("How many companies does Elon Musk run?")
# Out:
# ...
# Successfully saved https://en.wikipedia.org/wiki/Elon_Musk. New chunks count: 361
# "Elon Musk currently runs multiple companies. He is the founder, chairman, CEO, and chief technology officer of SpaceX. He is also involved with Tesla, where he serves as CEO. Additionally, he has been involved with other ventures such as SolarCity and The Boring Company. However, it is important to note that this information may not be up to date, as Elon Musk's business ventures are subject to change."

# %%
naval_chat_bot.add("web_page", "https://zhuanlan.zhihu.com/p/627829073")
naval_chat_bot.query("向量数据的计算方法都有哪些?")
# Out:
# Successfully saved https://zhuanlan.zhihu.com/p/627829073. New chunks count: 7
# '向量数据的计算方法包括向量相似度计算（如余弦相似度、欧几里得距离、曼哈顿距离等）、加权平均、向量内积、外积、矩阵乘法、池化、归一化等等。这些计算方法在推荐系统中评估用户和物品的相似度，以及在自然语言处理中评估文本或单词的相似度等应用中非常常见。'

# %%
naval_chat_bot.query("向量数据库都有哪些?能否介绍一下？")
# Out:
# '向量数据库是一种专门用于存储和处理向量数据的数据库。它们提供了高效的向量索引和查询功能，使得在大规模向量数据集上进行相似度搜索和计算变得更加快速和方便。\n\n以下是一些常见的向量数据库：\n\n1. Faiss：Faiss是Facebook AI Research开发的一种高性能向量数据库。它支持在大规模向量数据集上进行快速的相似度搜索和聚类操作。Faiss提供了多种索引结构，包括倒排索引、哈希索引和乘积量化索引等，以满足不同的应用需求。\n\n2. Annoy：Annoy是一种快速的近似最近邻搜索库，适用于大规模向量数据。它使用了一种基于树的索引结构，可以高效地进行相似度搜索和聚类操作。Annoy支持多种距离度量方法，包括欧几里得距离和余弦相似度等。\n\n3. Milvus：Milvus是一种开源的向量数据库，专门用于存储和处理大规模向量数据。它提供了高效的向量索引和查询功能，支持多种索引结构和距离度量方法。Milvus还提供了可视化的管理界面和丰富的API，方便用户进行向量数据的管理和操作。\n\n4. Elasticsearch：Elasticsearch是一种流行的分布式搜索和分析引擎，也可以用作向量数据库。它支持存储和索引向量数据，并提供了丰富的查询功能，包括相似度搜索和聚类操作。Elasticsearch还具有高可扩展性和灵活性，适用于处理大规模向量数据集。\n\n这些向量数据库都具有不同的特点和适用场景，选择适合自己需求的向量数据库可以提高向量数据的存储和处理效率。'
